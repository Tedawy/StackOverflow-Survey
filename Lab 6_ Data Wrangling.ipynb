# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify duplicate values in the dataset.
#
# *   Remove duplicate values from the dataset.
#
# *   Identify missing values in the dataset.
#
# *   Impute the missing values in the dataset.
#
# *   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
df.shape
# Out:
# (11552, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
# Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
print(f"Number of duplicated values: {df.duplicated().sum()} rows in dataset")
# Out:
# Number of duplicated values: 154 rows in dataset

# %%
#based on the quiz
df['Respondent'].duplicated().sum()
# Out:
# 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (11398, 85)

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here
print(f"Number of duplicated values: {df.duplicated().sum()} rows in dataset")
# Out:
# Number of duplicated values: 0 rows in dataset

# %%
#based on Normalize quiz
df['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %%
#based on the quiz
df['Respondent'].nunique()
# Out:
# 11398

# %%
#based on quiz
df['Country'].isnull().sum()
# Out:
# 0

# %%
#based on the quiz
df['EdLevel'].isnull().sum()
# Out:
# 112

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              5852
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           2706
# Some college/university study without earning a degree                                1361
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     516
# Associate degree                                                                       383
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              259
# Professional degree (JD, MD, etc.)                                                     154
# I never completed any formal education                                                  28
# Primary/elementary school                                                               27
# Name: EdLevel, dtype: int64

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time    10968
# Employed part-time      430
# Name: Employment, dtype: int64

# %%
df['WorkRemote'].value_counts()
# Out:
# Less than once per month / Never                           5100
# A few days each month                                      3213
# Less than half the time, but at least one day each week    1097
# All or almost all the time (I'm full-time remote)           961
# It's complicated                                            461
# More than half, but not all, the time                       299
# About half the time                                         259
# Name: WorkRemote, dtype: int64

# %%
df['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering          6953
# Information systems, information technology, or system administration     794
# Another engineering discipline (ex. civil, electrical, mechanical)        759
# Web development or web design                                             410
# A natural science (ex. biology, chemistry, physics)                       403
# Mathematics or statistics                                                 372
# A business discipline (ex. accounting, finance, marketing)                244
# A social science (ex. anthropology, psychology, political science)        210
# A humanities discipline (ex. literature, history, philosophy)             207
# Fine arts or performing arts (ex. graphic design, music, studio art)      161
# I never declared a major                                                  124
# A health science (ex. nursing, pharmacy, radiology)                        24
# Name: UndergradMajor, dtype: int64

# %%
df['ConvertedComp'].head()
# Out:
# 0     61000.0
# 1     95179.0
# 2     90000.0
# 3    455352.0
# 4     65277.0
# Name: ConvertedComp, dtype: float64

# %%
df['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
new_df = pd.DataFrame(df.isna().sum(),columns=['Number of Missing values'])
new_df.reset_index(drop=False,inplace=True)
new_df.rename(columns={'index':'Column Name'},inplace=True)
new_df.sort_values('Number of Missing values',ascending=False,inplace=True)
new_df.head(30)
# Out:
#                Column Name  Number of Missing values
# 57            BlockchainIs                      2610
# 39              CodeRevHrs                      2426
# 56           BlockchainOrg                      2322
# 51      MiscTechWorkedWith                      2182
# 76            SONewContent                      1965
# 69           SOHowMuchTime                      1917
# 50  WebFrameDesireNextYear                      1617
# 52  MiscTechDesireNextYear                      1455
# 49      WebFrameWorkedWith                      1393
# 71              SOPartFreq                      1128
# 46  DatabaseDesireNextYear                      1042
# 31           ConvertedComp                       816
# 29               CompTotal                       809
# 9           UndergradMajor                       737
# 81               Ethnicity                       675
# 48  PlatformDesireNextYear                       544
# 80               Sexuality                       542
# ...

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
df['WorkLoc'].isna().sum()
# Out:
# 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
df['WorkLoc'].value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %%
df['WorkLoc'].unique()
# Out:
# array(['Home', 'Office', 'Other place, such as a coworking space or cafe',
#        nan], dtype=object)

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference
df_work_loc = pd.DataFrame(df['WorkLoc'].value_counts())
df_work_loc.reset_index(drop=False, inplace=True)
#df_work_loc.shape
df_work_loc.rename(columns={'index':'Location','WorkLoc':'Count'},inplace=True)
df_work_loc
# Out:
#                                          Location  Count
# 0                                          Office   6806
# 1                                            Home   3589
# 2  Other place, such as a coworking space or cafe    971

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here
df['WorkLoc'].replace(np.nan,'Office',inplace=True)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
df['WorkLoc'].isna().sum()
# Out:
# 0

# %%
df['WorkLoc'].value_counts()
# Out:
# Office                                            6838
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
df['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %%
# your code goes here
df['CompFreq'].unique()
# Out:
# array(['Yearly', 'Monthly', 'Weekly', nan], dtype=object)

# %%
df['CompFreq'].isnull().sum()
# Out:
# 206

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# your code goes here
#df['NormalizedAnnualCompensation']

df.loc[df['CompFreq'] == 'Yearly', 'NormalizedAnnualCompensation'] = 1 * df['CompTotal']

df.loc[df['CompFreq'] == 'Monthly' ,'NormalizedAnnualCompensation'] = 12 * df['CompTotal']

df.loc[df['CompFreq'] == 'Weekly' ,'NormalizedAnnualCompensation'] = 52 *df['CompTotal']
df[['CompFreq','CompTotal','NormalizedAnnualCompensation']].head(30)
# Out:
#    CompFreq  CompTotal  NormalizedAnnualCompensation
# 0    Yearly    61000.0                       61000.0
# 1    Yearly   138000.0                      138000.0
# 2    Yearly    90000.0                       90000.0
# 3   Monthly    29000.0                      348000.0
# 4    Yearly    90000.0                       90000.0
# 5   Monthly     9500.0                      114000.0
# 6   Monthly     3000.0                       36000.0
# 7    Yearly   103000.0                      103000.0
# 8    Yearly    69000.0                       69000.0
# 9   Monthly     8000.0                       96000.0
# 10  Monthly     7000.0                       84000.0
# 11   Yearly   114000.0                      114000.0
# 12   Weekly     2000.0                      104000.0
# 13   Weekly    22000.0                     1144000.0
# 14  Monthly    96000.0                     1152000.0
# 15   Yearly   156000.0                      156000.0
# 16   Yearly    18000.0                       18000.0
# ...

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer\&utm_source=Exinfluencer\&utm_content=000026UJ\&utm_term=10006555\&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01\&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264\&cm_mmca1=000026UJ\&cm_mmca2=10006555\&cm_mmca3=M12345678\&cvosrc=email.Newsletter.M12345678\&cvo_campaign=000026UJ).
